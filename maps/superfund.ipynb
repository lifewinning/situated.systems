# %%
from bs4 import BeautifulSoup
import urllib, os

sites = open('silicon_superfunds/epa_links.txt','rb').read().split('\n')

for s in sites:
    soup = BeautifulSoup(urllib.urlopen(s))
    title = soup.title.string.replace('Superfund Site Overview ','').replace(', US EPA','')
# Out:
# Superfund Site Overview CTS Printex Inc., Pacific Southwest, US EPA
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
# document._domino_target = "_self";
# function _doClick(v, o, t) {
#   var returnValue = false;
#   var url="/r9/sfund/r9sfdocw.nsf/3dec8ba3252368428825742600743733/2451cac96089854f88257007005e9411!OpenDocument&Click=" + v;
#   if (o.href != null) {
#     o.href = url;
#     returnValue = true;
#   } else {
#     if (t == null)
#       t = document._domino_target;
#     window.open(url, t);
#   }
#   return returnValue;
# }
# // -->
#
#
#
#
#
#
# Jump to main content or area navigation.
#
#
#
#
#
# A-Z Index
# Advanced Search
#
#
# What are you looking for?
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
# Learn the Issues
# Science & Technology
# Laws & Regulations
# About EPA
#
#
#
#
# Contact Us
# Pacific Southwest, Region 9: Superfund
# Serving Arizona, California, Hawaii, Nevada, the Pacific Islands, and Tribal Nations
#
#
#
#
# ...
